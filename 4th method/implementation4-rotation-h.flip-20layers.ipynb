# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
IMG_SIZE = 224
batch_size = 32
NUM_CLASSES = 2
LEARNING_RATE = 0.001

# %%
train_dir = 'D:/Zuyyina Hawani_09040620070/trypo_split/trypo_train'
validation_dir = 'D:/Zuyyina Hawani_09040620070/trypo_split/trypo_valid'
test_dir = 'D:/Zuyyina Hawani_09040620070/trypophobia/test'

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    seed=123
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    validation_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    seed=123
)
test_gen = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    color_mode='rgb',
    shuffle='False',
    seed=123
)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 12706 files belonging to 2 classes.
# Found 3178 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# ['1. Trypophobia', '2. Normal']

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(factor=0.25, fill_mode='nearest'),
        tf.keras.layers.RandomFlip(mode='horizontal'),
    ],
    name="img_augmentation",
)
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(x)


model = tf.keras.Model(inputs, outputs)
model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"]
)
    
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  img_augmentation (Sequenti  (None, 224, 224, 3)       0
#  al)
#
#  efficientnetb0 (Functional  (None, 2)                 4052133
#  )
#
# =================================================================
# Total params: 4052133 (15.46 MB)
# Trainable params: 4010110 (15.30 MB)
# Non-trainable params: 42023 (164.16 KB)
# _________________________________________________________________

# %%
def build_model(num_classes, input_shape):
    inputs = layers.Input(shape=input_shape)
    x = inputs
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="sigmoid", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy',
              metrics=['accuracy'])
    return model

# %%
model = build_model(num_classes=NUM_CLASSES, input_shape=(IMG_SIZE, IMG_SIZE, 3))

epochs = 15

model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 398/398 - 615s - loss: 0.2693 - accuracy: 0.9013 - val_loss: 0.1819 - val_accuracy: 0.9352 - 615s/epoch - 2s/step
# Epoch 2/15
# 398/398 - 535s - loss: 0.2005 - accuracy: 0.9251 - val_loss: 0.1707 - val_accuracy: 0.9374 - 535s/epoch - 1s/step
# Epoch 3/15
# 398/398 - 537s - loss: 0.1912 - accuracy: 0.9305 - val_loss: 0.1678 - val_accuracy: 0.9380 - 537s/epoch - 1s/step
# Epoch 4/15
# 398/398 - 535s - loss: 0.1819 - accuracy: 0.9314 - val_loss: 0.1658 - val_accuracy: 0.9396 - 535s/epoch - 1s/step
# Epoch 5/15
# 398/398 - 538s - loss: 0.1784 - accuracy: 0.9314 - val_loss: 0.1648 - val_accuracy: 0.9364 - 538s/epoch - 1s/step
# Epoch 6/15
# 398/398 - 535s - loss: 0.1828 - accuracy: 0.9303 - val_loss: 0.1650 - val_accuracy: 0.9383 - 535s/epoch - 1s/step
# Epoch 7/15
# 398/398 - 537s - loss: 0.1840 - accuracy: 0.9296 - val_loss: 0.1654 - val_accuracy: 0.9399 - 537s/epoch - 1s/step
# Epoch 8/15
# 398/398 - 538s - loss: 0.1778 - accuracy: 0.9346 - val_loss: 0.1661 - val_accuracy: 0.9368 - 538s/epoch - 1s/step
# Epoch 9/15
# 398/398 - 535s - loss: 0.1765 - accuracy: 0.9342 - val_loss: 0.1647 - val_accuracy: 0.9399 - 535s/epoch - 1s/step
# Epoch 10/15
# 398/398 - 538s - loss: 0.1847 - accuracy: 0.9281 - val_loss: 0.1669 - val_accuracy: 0.9415 - 538s/epoch - 1s/step
# Epoch 11/15
# 398/398 - 538s - loss: 0.1829 - accuracy: 0.9300 - val_loss: 0.1666 - val_accuracy: 0.9399 - 538s/epoch - 1s/step
# Epoch 12/15
# 398/398 - 533s - loss: 0.1777 - accuracy: 0.9320 - val_loss: 0.1669 - val_accuracy: 0.9371 - 533s/epoch - 1s/step
# Epoch 13/15
# 398/398 - 533s - loss: 0.1722 - accuracy: 0.9355 - val_loss: 0.1668 - val_accuracy: 0.9386 - 533s/epoch - 1s/step
# Epoch 14/15
# 398/398 - 538s - loss: 0.1768 - accuracy: 0.9324 - val_loss: 0.1659 - val_accuracy: 0.9368 - 538s/epoch - 1s/step
# Epoch 15/15
# 398/398 - 501s - loss: 0.1803 - accuracy: 0.9314 - val_loss: 0.1661 - val_accuracy: 0.9399 - 501s/epoch - 1s/step

# %%
# Evaluasi model pada dataset pengujian
test_loss, test_accuracy = model.evaluate(test_gen)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 32/32 [==============================] - 34s 1s/step - loss: 0.1716 - accuracy: 0.9300
# Test Loss: 0.17157961428165436
# Test Accuracy: 0.9300000071525574

# %%
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy',
              metrics=['accuracy'])

unfreeze_model(model)

epochs = 15

model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/15
# 398/398 - 463s - loss: 0.2239 - accuracy: 0.9253 - val_loss: 0.1523 - val_accuracy: 0.9475 - 463s/epoch - 1s/step
# Epoch 2/15
# 398/398 - 394s - loss: 0.1192 - accuracy: 0.9575 - val_loss: 0.1590 - val_accuracy: 0.9478 - 394s/epoch - 989ms/step
# Epoch 3/15
# 398/398 - 394s - loss: 0.0925 - accuracy: 0.9665 - val_loss: 0.1591 - val_accuracy: 0.9512 - 394s/epoch - 989ms/step
# Epoch 4/15
# 398/398 - 393s - loss: 0.0668 - accuracy: 0.9765 - val_loss: 0.1874 - val_accuracy: 0.9493 - 393s/epoch - 988ms/step
# Epoch 5/15
# 398/398 - 394s - loss: 0.0522 - accuracy: 0.9817 - val_loss: 0.1875 - val_accuracy: 0.9434 - 394s/epoch - 989ms/step
# Epoch 6/15
# 398/398 - 395s - loss: 0.0426 - accuracy: 0.9854 - val_loss: 0.1962 - val_accuracy: 0.9481 - 395s/epoch - 993ms/step
# Epoch 7/15
# 398/398 - 393s - loss: 0.0464 - accuracy: 0.9836 - val_loss: 0.2221 - val_accuracy: 0.9475 - 393s/epoch - 988ms/step
# Epoch 8/15
# 398/398 - 393s - loss: 0.0322 - accuracy: 0.9885 - val_loss: 0.2397 - val_accuracy: 0.9487 - 393s/epoch - 987ms/step
# Epoch 9/15
# 398/398 - 394s - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.2339 - val_accuracy: 0.9475 - 394s/epoch - 991ms/step
# Epoch 10/15
# 398/398 - 394s - loss: 0.0280 - accuracy: 0.9910 - val_loss: 0.2478 - val_accuracy: 0.9522 - 394s/epoch - 990ms/step
# Epoch 11/15
# 398/398 - 394s - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.2075 - val_accuracy: 0.9550 - 394s/epoch - 991ms/step
# Epoch 12/15
# 398/398 - 395s - loss: 0.0227 - accuracy: 0.9922 - val_loss: 0.2399 - val_accuracy: 0.9503 - 395s/epoch - 993ms/step
# Epoch 13/15
# 398/398 - 394s - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.2142 - val_accuracy: 0.9490 - 394s/epoch - 991ms/step
# Epoch 14/15
# 398/398 - 398s - loss: 0.0212 - accuracy: 0.9922 - val_loss: 0.2516 - val_accuracy: 0.9509 - 398s/epoch - 1s/step
# Epoch 15/15
# 398/398 - 277s - loss: 0.0294 - accuracy: 0.9899 - val_loss: 0.2294 - val_accuracy: 0.9509 - 277s/epoch - 695ms/step

# %%
# Evaluasi model pada dataset pengujian
test_loss, test_accuracy = model.evaluate(test_gen)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 32/32 [==============================] - 12s 363ms/step - loss: 0.1770 - accuracy: 0.9690
# Test Loss: 0.17699700593948364
# Test Accuracy: 0.968999981880188

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np 

tes = test_gen.batch(batch_size)
y_true = []
y_pred = []
for x, y in test_gen:
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))
    
# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Calculate accuracy, precision, and recall
TP = np.diag(cm)
FP = np.sum(cm, axis=0) - TP
FN = np.sum(cm, axis=1) - TP
TN = np.sum(cm) - (TP + FP + FN)
accuracy = np.mean((TP + TN) / (TP + TN + FP + FN))
precision = np.mean(TP / (TP + FP))
recall = np.mean(TP / (TP + FN))
f1_score = 2 * (precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)

# Visualize confusion matrix
sns.heatmap(cm, annot=True, cmap="Greys", fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 1s 1s/step
# Accuracy: 0.969
# Precision: 0.9694224802322089
# Recall: 0.969
# F1-score: 0.9692111940762065

# %%
model.save('implementation4_20layers.h5',save_format='h5')
# Out:
# C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
