# %%
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
IMG_SIZE = 224
batch_size = 32
NUM_CLASSES = 2
LEARNING_RATE = 0.001

# %%
train_dir = 'D:/Zuyyina Hawani_09040620070/trypo_split/trypo_train'
validation_dir = 'D:/Zuyyina Hawani_09040620070/trypo_split/trypo_valid'
test_dir = 'D:/Zuyyina Hawani_09040620070/trypophobia/tes'

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    seed=123
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    validation_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    seed=123
)
test_gen = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    color_mode='rgb',
    shuffle='False',
    seed=123
)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 12706 files belonging to 2 classes.
# Found 3178 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# ['1. Trypophobia', '2. Normal']

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(factor=0.25, fill_mode='nearest'),
        tf.keras.layers.RandomFlip(mode='horizontal'),
        tf.keras.layers.RandomZoom(height_factor=-0.3, width_factor=0.3, fill_mode='nearest'),
    ],
    name="img_augmentation",
)
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(x)


model = tf.keras.Model(inputs, outputs)
model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"]
)
    
model.summary()
epochs = 15
model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  img_augmentation (Sequenti  (None, 224, 224, 3)       0
#  al)
#
#  efficientnetb0 (Functional  (None, 2)                 4052133
#  )
#
# =================================================================
# Total params: 4052133 (15.46 MB)
# Trainable params: 4010110 (15.30 MB)
# Non-trainable params: 42023 (164.16 KB)
# _________________________________________________________________
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 398/398 - 2234s - loss: 0.8730 - accuracy: 0.6840 - val_loss: 0.5281 - val_accuracy: 0.7587 - 2234s/epoch - 6s/step
# Epoch 2/15
# 398/398 - 2021s - loss: 0.5355 - accuracy: 0.7463 - val_loss: 0.4600 - val_accuracy: 0.8021 - 2021s/epoch - 5s/step
# Epoch 3/15
# 398/398 - 2024s - loss: 0.4987 - accuracy: 0.7737 - val_loss: 2.9275 - val_accuracy: 0.5205 - 2024s/epoch - 5s/step
# Epoch 4/15
# 398/398 - 1947s - loss: 0.5039 - accuracy: 0.7692 - val_loss: 0.4152 - val_accuracy: 0.8059 - 1947s/epoch - 5s/step
# Epoch 5/15
# 398/398 - 2024s - loss: 0.4225 - accuracy: 0.8054 - val_loss: 0.3798 - val_accuracy: 0.8354 - 2024s/epoch - 5s/step
# Epoch 6/15
# 398/398 - 2032s - loss: 0.4071 - accuracy: 0.8169 - val_loss: 0.8924 - val_accuracy: 0.8307 - 2032s/epoch - 5s/step
# Epoch 7/15
# 398/398 - 2039s - loss: 0.4025 - accuracy: 0.8231 - val_loss: 0.3688 - val_accuracy: 0.8427 - 2039s/epoch - 5s/step
# Epoch 8/15
# 398/398 - 2041s - loss: 0.4024 - accuracy: 0.8232 - val_loss: 0.3734 - val_accuracy: 0.8285 - 2041s/epoch - 5s/step
# Epoch 9/15
# 398/398 - 878s - loss: 0.3685 - accuracy: 0.8387 - val_loss: 0.3717 - val_accuracy: 0.8235 - 878s/epoch - 2s/step
# Epoch 10/15
# 398/398 - 740s - loss: 0.3563 - accuracy: 0.8443 - val_loss: 0.3229 - val_accuracy: 0.8656 - 740s/epoch - 2s/step
# Epoch 11/15
# 398/398 - 740s - loss: 0.3502 - accuracy: 0.8527 - val_loss: 0.3586 - val_accuracy: 0.8534 - 740s/epoch - 2s/step
# Epoch 12/15
# 398/398 - 739s - loss: 0.3287 - accuracy: 0.8566 - val_loss: 0.3562 - val_accuracy: 0.8480 - 739s/epoch - 2s/step
# Epoch 13/15
# 398/398 - 1380s - loss: 0.3338 - accuracy: 0.8561 - val_loss: 0.3804 - val_accuracy: 0.8247 - 1380s/epoch - 3s/step
# Epoch 14/15
# 398/398 - 2032s - loss: 0.3166 - accuracy: 0.8627 - val_loss: 0.3352 - val_accuracy: 0.8546 - 2032s/epoch - 5s/step
# Epoch 15/15
# 398/398 - 2036s - loss: 0.3221 - accuracy: 0.8627 - val_loss: 0.3193 - val_accuracy: 0.8644 - 2036s/epoch - 5s/step

# %%
def build_model(num_classes, input_shape):
    inputs = layers.Input(shape=input_shape)
    x = inputs
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="sigmoid", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy',
              metrics=['accuracy'])
    return model

# %%
model = build_model(num_classes=NUM_CLASSES, input_shape=(IMG_SIZE, IMG_SIZE, 3))

epochs = 15
model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 398/398 - 275s - loss: 0.2660 - accuracy: 0.9019 - val_loss: 0.1838 - val_accuracy: 0.9320 - 275s/epoch - 692ms/step
# Epoch 2/15
# 398/398 - 509s - loss: 0.2008 - accuracy: 0.9255 - val_loss: 0.1742 - val_accuracy: 0.9383 - 509s/epoch - 1s/step
# Epoch 3/15
# 398/398 - 522s - loss: 0.1949 - accuracy: 0.9299 - val_loss: 0.1682 - val_accuracy: 0.9393 - 522s/epoch - 1s/step
# Epoch 4/15
# 398/398 - 521s - loss: 0.1825 - accuracy: 0.9326 - val_loss: 0.1671 - val_accuracy: 0.9399 - 521s/epoch - 1s/step
# Epoch 5/15
# 398/398 - 524s - loss: 0.1807 - accuracy: 0.9307 - val_loss: 0.1647 - val_accuracy: 0.9390 - 524s/epoch - 1s/step
# Epoch 6/15
# 398/398 - 521s - loss: 0.1803 - accuracy: 0.9313 - val_loss: 0.1648 - val_accuracy: 0.9377 - 521s/epoch - 1s/step
# Epoch 7/15
# 398/398 - 520s - loss: 0.1812 - accuracy: 0.9299 - val_loss: 0.1657 - val_accuracy: 0.9412 - 520s/epoch - 1s/step
# Epoch 8/15
# 398/398 - 518s - loss: 0.1813 - accuracy: 0.9296 - val_loss: 0.1630 - val_accuracy: 0.9386 - 518s/epoch - 1s/step
# Epoch 9/15
# 398/398 - 522s - loss: 0.1861 - accuracy: 0.9292 - val_loss: 0.1678 - val_accuracy: 0.9380 - 522s/epoch - 1s/step
# Epoch 10/15
# 398/398 - 525s - loss: 0.1798 - accuracy: 0.9316 - val_loss: 0.1692 - val_accuracy: 0.9405 - 525s/epoch - 1s/step
# Epoch 11/15
# 398/398 - 523s - loss: 0.1795 - accuracy: 0.9307 - val_loss: 0.1669 - val_accuracy: 0.9383 - 523s/epoch - 1s/step
# Epoch 12/15
# 398/398 - 522s - loss: 0.1782 - accuracy: 0.9315 - val_loss: 0.1649 - val_accuracy: 0.9374 - 522s/epoch - 1s/step
# Epoch 13/15
# 398/398 - 523s - loss: 0.1712 - accuracy: 0.9355 - val_loss: 0.1652 - val_accuracy: 0.9396 - 523s/epoch - 1s/step
# Epoch 14/15
# 398/398 - 523s - loss: 0.1750 - accuracy: 0.9318 - val_loss: 0.1685 - val_accuracy: 0.9368 - 523s/epoch - 1s/step
# Epoch 15/15
# 398/398 - 522s - loss: 0.1802 - accuracy: 0.9334 - val_loss: 0.1676 - val_accuracy: 0.9396 - 522s/epoch - 1s/step

# %%
# Evaluasi model pada dataset pengujian
test_loss, test_accuracy = model.evaluate(test_gen)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 32/32 [==============================] - 33s 1s/step - loss: 0.1743 - accuracy: 0.9220
# Test Loss: 0.17431475222110748
# Test Accuracy: 0.921999990940094

# %%
def unfreeze_model(model):
    # We unfreeze the top 10 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-10:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy',
              metrics=['accuracy'])

unfreeze_model(model)

epochs = 15

model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/15
# 398/398 - 573s - loss: 0.2236 - accuracy: 0.9237 - val_loss: 0.1671 - val_accuracy: 0.9449 - 573s/epoch - 1s/step
# Epoch 2/15
# 398/398 - 526s - loss: 0.1262 - accuracy: 0.9531 - val_loss: 0.1604 - val_accuracy: 0.9430 - 526s/epoch - 1s/step
# Epoch 3/15
# 398/398 - 553s - loss: 0.0897 - accuracy: 0.9685 - val_loss: 0.1755 - val_accuracy: 0.9497 - 553s/epoch - 1s/step
# Epoch 4/15
# 398/398 - 552s - loss: 0.0747 - accuracy: 0.9725 - val_loss: 0.1686 - val_accuracy: 0.9471 - 552s/epoch - 1s/step
# Epoch 5/15
# 398/398 - 551s - loss: 0.0599 - accuracy: 0.9766 - val_loss: 0.1911 - val_accuracy: 0.9434 - 551s/epoch - 1s/step
# Epoch 6/15
# 398/398 - 551s - loss: 0.0557 - accuracy: 0.9796 - val_loss: 0.1683 - val_accuracy: 0.9515 - 551s/epoch - 1s/step
# Epoch 7/15
# 398/398 - 551s - loss: 0.0542 - accuracy: 0.9801 - val_loss: 0.1862 - val_accuracy: 0.9427 - 551s/epoch - 1s/step
# Epoch 8/15
# 398/398 - 549s - loss: 0.0543 - accuracy: 0.9808 - val_loss: 0.2091 - val_accuracy: 0.9440 - 549s/epoch - 1s/step
# Epoch 9/15
# 398/398 - 553s - loss: 0.0443 - accuracy: 0.9853 - val_loss: 0.2261 - val_accuracy: 0.9459 - 553s/epoch - 1s/step
# Epoch 10/15
# 398/398 - 553s - loss: 0.0413 - accuracy: 0.9854 - val_loss: 0.2212 - val_accuracy: 0.9462 - 553s/epoch - 1s/step
# Epoch 11/15
# 398/398 - 556s - loss: 0.0371 - accuracy: 0.9867 - val_loss: 0.2232 - val_accuracy: 0.9386 - 556s/epoch - 1s/step
# Epoch 12/15
# 398/398 - 553s - loss: 0.0486 - accuracy: 0.9836 - val_loss: 0.2465 - val_accuracy: 0.9396 - 553s/epoch - 1s/step
# Epoch 13/15
# 398/398 - 554s - loss: 0.0476 - accuracy: 0.9817 - val_loss: 0.2008 - val_accuracy: 0.9475 - 554s/epoch - 1s/step
# Epoch 14/15
# 398/398 - 555s - loss: 0.0331 - accuracy: 0.9884 - val_loss: 0.2110 - val_accuracy: 0.9478 - 555s/epoch - 1s/step
# Epoch 15/15
# 398/398 - 555s - loss: 0.0458 - accuracy: 0.9838 - val_loss: 0.2028 - val_accuracy: 0.9493 - 555s/epoch - 1s/step

# %%
# Evaluasi model pada dataset pengujian
test_loss, test_accuracy = model.evaluate(test_gen)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 32/32 [==============================] - 34s 1s/step - loss: 0.2211 - accuracy: 0.9430
# Test Loss: 0.2210797667503357
# Test Accuracy: 0.9430000185966492

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

test_ds = test_gen.batch(batch_size)
y_true = []
y_pred = []
for x, y in test_gen:
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Calculate accuracy, precision, and recall
TP = np.diag(cm)
FP = np.sum(cm, axis=0) - TP
FN = np.sum(cm, axis=1) - TP
TN = np.sum(cm) - (TP + FP + FN)
accuracy = np.mean((TP + TN) / (TP + TN + FP + FN))
precision = np.mean(TP / (TP + FP))
recall = np.mean(TP / (TP + FN))
f1_score = 2 * (precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)

# Visualize confusion matrix
sns.heatmap(cm, annot=True, cmap="Greys", fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 112ms/step
# Accuracy: 0.943
# Precision: 0.9436406170510216
# Recall: 0.9430000000000001
# F1-score: 0.9433201997633538

# %%
model.save('implementation5_10layers.h5',save_format='h5')
# Out:
# C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
