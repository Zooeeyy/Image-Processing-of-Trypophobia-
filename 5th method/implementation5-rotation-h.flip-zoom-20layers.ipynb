# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
IMG_SIZE = 224
batch_size = 32
NUM_CLASSES = 2
LEARNING_RATE = 0.001

# %%
train_dir = 'D:/Zuyyina Hawani_09040620070/trypo_split/trypo_train'
validation_dir = 'D:/Zuyyina Hawani_09040620070/trypo_split/trypo_valid'
test_dir = 'D:/Zuyyina Hawani_09040620070/trypophobia/tes'

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    seed=123
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    validation_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    seed=123
)
test_gen = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
    color_mode='rgb',
    shuffle='False',
    seed=123
)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 12706 files belonging to 2 classes.
# Found 3178 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# ['1. Trypophobia', '2. Normal']

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(factor=0.25, fill_mode='nearest'),
        tf.keras.layers.RandomFlip(mode='horizontal'),
        tf.keras.layers.RandomZoom(height_factor=-0.3, width_factor=0.3, fill_mode='nearest'),
    ],
    name="img_augmentation",
)
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(x)


model = tf.keras.Model(inputs, outputs)
model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"]
)
    
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  img_augmentation (Sequenti  (None, 224, 224, 3)       0
#  al)
#
#  efficientnetb0 (Functional  (None, 2)                 4052133
#  )
#
# =================================================================
# Total params: 4052133 (15.46 MB)
# Trainable params: 4010110 (15.30 MB)
# Non-trainable params: 42023 (164.16 KB)
# _________________________________________________________________

# %%
def build_model(num_classes, input_shape):
    inputs = layers.Input(shape=input_shape)
    x = inputs
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="sigmoid", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy',
              metrics=['accuracy'])
    return model

# %%
model = build_model(num_classes=NUM_CLASSES, input_shape=(IMG_SIZE, IMG_SIZE, 3))

epochs = 15

model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 398/398 - 591s - loss: 0.2674 - accuracy: 0.9009 - val_loss: 0.1784 - val_accuracy: 0.9386 - 591s/epoch - 1s/step
# Epoch 2/15
# 398/398 - 528s - loss: 0.2009 - accuracy: 0.9263 - val_loss: 0.1677 - val_accuracy: 0.9440 - 528s/epoch - 1s/step
# Epoch 3/15
# 398/398 - 528s - loss: 0.1926 - accuracy: 0.9311 - val_loss: 0.1645 - val_accuracy: 0.9405 - 528s/epoch - 1s/step
# Epoch 4/15
# 398/398 - 524s - loss: 0.1816 - accuracy: 0.9306 - val_loss: 0.1680 - val_accuracy: 0.9393 - 524s/epoch - 1s/step
# Epoch 5/15
# 398/398 - 527s - loss: 0.1851 - accuracy: 0.9310 - val_loss: 0.1657 - val_accuracy: 0.9364 - 527s/epoch - 1s/step
# Epoch 6/15
# 398/398 - 526s - loss: 0.1770 - accuracy: 0.9340 - val_loss: 0.1663 - val_accuracy: 0.9364 - 526s/epoch - 1s/step
# Epoch 7/15
# 398/398 - 530s - loss: 0.1811 - accuracy: 0.9310 - val_loss: 0.1663 - val_accuracy: 0.9371 - 530s/epoch - 1s/step
# Epoch 8/15
# 398/398 - 527s - loss: 0.1805 - accuracy: 0.9300 - val_loss: 0.1643 - val_accuracy: 0.9390 - 527s/epoch - 1s/step
# Epoch 9/15
# 398/398 - 528s - loss: 0.1823 - accuracy: 0.9320 - val_loss: 0.1634 - val_accuracy: 0.9377 - 528s/epoch - 1s/step
# Epoch 10/15
# 398/398 - 528s - loss: 0.1778 - accuracy: 0.9340 - val_loss: 0.1675 - val_accuracy: 0.9393 - 528s/epoch - 1s/step
# Epoch 11/15
# 398/398 - 527s - loss: 0.1791 - accuracy: 0.9333 - val_loss: 0.1711 - val_accuracy: 0.9364 - 527s/epoch - 1s/step
# Epoch 12/15
# 398/398 - 527s - loss: 0.1799 - accuracy: 0.9318 - val_loss: 0.1678 - val_accuracy: 0.9390 - 527s/epoch - 1s/step
# Epoch 13/15
# 398/398 - 527s - loss: 0.1726 - accuracy: 0.9359 - val_loss: 0.1672 - val_accuracy: 0.9368 - 527s/epoch - 1s/step
# Epoch 14/15
# 398/398 - 516s - loss: 0.1730 - accuracy: 0.9334 - val_loss: 0.1691 - val_accuracy: 0.9380 - 516s/epoch - 1s/step
# Epoch 15/15
# 398/398 - 470s - loss: 0.1801 - accuracy: 0.9356 - val_loss: 0.1674 - val_accuracy: 0.9383 - 470s/epoch - 1s/step

# %%
# Evaluasi model pada dataset pengujian
test_loss, test_accuracy = model.evaluate(test_gen)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 32/32 [==============================] - 33s 1s/step - loss: 0.1744 - accuracy: 0.9250
# Test Loss: 0.17442400753498077
# Test Accuracy: 0.925000011920929

# %%
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
              loss='binary_crossentropy',
              metrics=['accuracy'])

unfreeze_model(model)

epochs = 15

model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/15
# 398/398 - 655s - loss: 0.2211 - accuracy: 0.9270 - val_loss: 0.1434 - val_accuracy: 0.9500 - 655s/epoch - 2s/step
# Epoch 2/15
# 398/398 - 579s - loss: 0.1171 - accuracy: 0.9569 - val_loss: 0.1435 - val_accuracy: 0.9481 - 579s/epoch - 1s/step
# Epoch 3/15
# 398/398 - 580s - loss: 0.0910 - accuracy: 0.9686 - val_loss: 0.1833 - val_accuracy: 0.9471 - 580s/epoch - 1s/step
# Epoch 4/15
# 398/398 - 579s - loss: 0.0669 - accuracy: 0.9765 - val_loss: 0.1587 - val_accuracy: 0.9509 - 579s/epoch - 1s/step
# Epoch 5/15
# 398/398 - 576s - loss: 0.0473 - accuracy: 0.9846 - val_loss: 0.1963 - val_accuracy: 0.9509 - 576s/epoch - 1s/step
# Epoch 6/15
# 398/398 - 581s - loss: 0.0466 - accuracy: 0.9846 - val_loss: 0.1942 - val_accuracy: 0.9515 - 581s/epoch - 1s/step
# Epoch 7/15
# 398/398 - 579s - loss: 0.0376 - accuracy: 0.9871 - val_loss: 0.2234 - val_accuracy: 0.9478 - 579s/epoch - 1s/step
# Epoch 8/15
# 398/398 - 579s - loss: 0.0376 - accuracy: 0.9873 - val_loss: 0.2182 - val_accuracy: 0.9506 - 579s/epoch - 1s/step
# Epoch 9/15
# 398/398 - 576s - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.2187 - val_accuracy: 0.9544 - 576s/epoch - 1s/step
# Epoch 10/15
# 398/398 - 579s - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.2436 - val_accuracy: 0.9525 - 579s/epoch - 1s/step
# Epoch 11/15
# 398/398 - 579s - loss: 0.0321 - accuracy: 0.9906 - val_loss: 0.1848 - val_accuracy: 0.9556 - 579s/epoch - 1s/step
# Epoch 12/15
# 398/398 - 578s - loss: 0.0356 - accuracy: 0.9889 - val_loss: 0.1952 - val_accuracy: 0.9519 - 578s/epoch - 1s/step
# Epoch 13/15
# 398/398 - 576s - loss: 0.0344 - accuracy: 0.9880 - val_loss: 0.1998 - val_accuracy: 0.9509 - 576s/epoch - 1s/step
# Epoch 14/15
# 398/398 - 466s - loss: 0.0197 - accuracy: 0.9928 - val_loss: 0.2069 - val_accuracy: 0.9553 - 466s/epoch - 1s/step
# Epoch 15/15
# 398/398 - 219s - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.2334 - val_accuracy: 0.9519 - 219s/epoch - 551ms/step

# %%
# Evaluasi model pada dataset pengujian
test_loss, test_accuracy = model.evaluate(test_gen)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# 32/32 [==============================] - 12s 368ms/step - loss: 0.2386 - accuracy: 0.9560
# Test Loss: 0.2385547012090683
# Test Accuracy: 0.9559999704360962

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np 

test_ds = test_gen.batch(batch_size)
y_true = []
y_pred = []
for x, y in test_gen:
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)
print(cm)

# Calculate accuracy, precision, and recall
TP = np.diag(cm)
FP = np.sum(cm, axis=0) - TP
FN = np.sum(cm, axis=1) - TP
TN = np.sum(cm) - (TP + FP + FN)
accuracy = np.mean((TP + TN) / (TP + TN + FP + FN))
precision = np.mean(TP / (TP + FP))
recall = np.mean(TP / (TP + FN))
f1_score = 2 * (precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)

# Visualize confusion matrix
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 1s 1s/step
# [[474  26]
#  [ 18 482]]
# Accuracy: 0.956
# Precision: 0.9561167658920684
# Recall: 0.956
# F1-score: 0.9560583793808038

# %%
model.save('implementation5_20layers.h5',save_format='h5')
# Out:
# C:\Users\User\.conda\envs\zuyyinapy\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
